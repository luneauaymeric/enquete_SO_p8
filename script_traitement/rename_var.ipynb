# %%
import csv
import pandas as pd
import re

# %%
df0 = pd.read_csv('buparis8_chercheurs_besoins_accompagnement_4-3-2026_15_41.csv', sep =",")

# %%
df_col = pd.read_csv("dico_variable.csv", sep = ",")
dict_new_col = dict(zip(df_col.name, df_col.label.str.lower()))

df = df0.rename(columns=dict_new_col)
df
